# %% [markdown]
# # Flask 연습 및 실습 코드

# %% [markdown]
# ## Flask 설치
# 로컬 환경에서는 flask만 설치해 주면 가능하지만, colab이라는 특수 환경에서는 flask-ngrok을 추가적으로 설치 해 주어야 합니다.

# %%
# !pip install flask --quiet
# !pip install flask-ngrok --quiet
print("Completed!")
# Out:
# Completed!

# %%
# ngrok website에서 linux 버전 ngrok 설치 - https://dashboard.ngrok.com/get-started/setup

# !wget https://bin.equinox.io/c/4VmDzA7iaHb/ngrok-stable-linux-amd64.tgz
# Out:
# --2022-09-24 05:52:13--  https://bin.equinox.io/c/4VmDzA7iaHb/ngrok-stable-linux-amd64.tgz
# Resolving bin.equinox.io (bin.equinox.io)... 54.161.241.46, 54.237.133.81, 52.202.168.65, ...
# Connecting to bin.equinox.io (bin.equinox.io)|54.161.241.46|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 13770165 (13M) [application/octet-stream]
# Saving to: ‘ngrok-stable-linux-amd64.tgz.2’
#
# ngrok-stable-linux- 100%[===================>]  13.13M  19.0MB/s    in 0.7s
#
# 2022-09-24 05:52:14 (19.0 MB/s) - ‘ngrok-stable-linux-amd64.tgz.2’ saved [13770165/13770165]

# %%
# linux ngrok을 설치 후 압축을 풀어주는 과정

# !tar -xvf /content/ngrok-stable-linux-amd64.tgz
# Out:
# ngrok

# %% [markdown]
# ngrok flask를 사용하기 위해서는 자신의 계정 생성이 필요합니다.
#
# https://ngrok.com/
#
# 위 주소로 접속하여 계정 생성 후 자신의 Authtoken을 찾아줍니다.

# %%
# ngrok 홈페이지 계정 생성 후 자신의 Authtoken을 입력해 주어야 사용 가능

# !./ngrok authtoken 2DF6RBrbkoLyIimzEBcSp6Kd06e_39qFt65ajfn14paEhxMvN
# Out:
# Authtoken saved to configuration file: /root/.ngrok2/ngrok.yml

# %%
# import Flask from flask module
from flask import Flask

# import run_with_ngrok from flask_ngrok to run the app using ngrok
from flask_ngrok import run_with_ngrok

# %% [markdown]
# # Flask 시작하기
# 내가 만든 웹사이트 접속하기

# %%
app = Flask(__name__)
run_with_ngrok(app)    #Flask 시작할 때 이 두 코딩은 고정 #익숙해지고 이해하기 

@app.route('/') #홈페이지에 제일 먼저 들어갈 때의 화면을 표현 
def home(): 
     return f"<h1>Welcome to Flask World<h1/>"

app.run()
# Out:
#  * Serving Flask app "__main__" (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: off
# INFO:werkzeug: * Running on http://127.0.0.1:5000/ (Press CTRL+C to quit)
#  * Running on http://9148-104-199-114-222.ngrok.io
#  * Traffic stats available on http://127.0.0.1:4040
# INFO:werkzeug:127.0.0.1 - - [24/Sep/2022 05:59:37] "GET / HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [24/Sep/2022 05:59:38] "GET /favicon.ico HTTP/1.1" 404 -

# %% [markdown]
# ## Routing
# 폴더 내에 파일 주소를 할당하듯이 각각 routing된 url 하나를 하나의 HTML파일로 생각해서 진행하게 됩니다.
#
# 이 부분에서 각각의 정의된 함수와 그 output을 HTML형식의 출력물로 내보내 주어 파일을 만들 수 있고 그 과정에서의 변수를 꺽쇠를 이용하여 입력값으로 사용할 수 있습니다.

# %%
app = Flask(__name__)
run_with_ngrok(app)

@app.route('/')
def home():
     return f"<h1>This is your main homepage!</h1>"

@app.route('/create/')
def create():
     return f"<h1>Welcome to create homepage!</h1>"

@app.route('/readid/')
def read():
     return f"<h1>Welcome to readid homepage! If you want readid, change your id url</h1>"

@app.route('/readid/<id>/')
def readid(id):
     return f"<h1>Welcome to readid homepage! Hello {id}!</h1>"

app.run()
# Out:
#  * Serving Flask app "__main__" (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: off
# INFO:werkzeug: * Running on http://127.0.0.1:5000/ (Press CTRL+C to quit)
#  * Running on http://0ee4-104-199-114-222.ngrok.io
#  * Traffic stats available on http://127.0.0.1:4040
# INFO:werkzeug:127.0.0.1 - - [24/Sep/2022 05:59:59] "GET / HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [24/Sep/2022 06:00:00] "GET /favicon.ico HTTP/1.1" 404 -

# %% [markdown]
# python의 변수를 활용해서 입력된 변수에 맞게 서로 다른 페이지로 손쉽게 이동할 수 있도록 만듭니다.

# %%
app = Flask(__name__)
run_with_ngrok(app)

@app.route('/')
def home():
     return f'''<!doctype html>
     <html>
      <body>
        <h1>Welcome to your homepage</h1>
        <ol>
          <li><a href = "/read/1/">Click this part!</a></li>
          <li><a href = "/read/2/">Now, click this part!</a></li>
          <li><a href = "/read/3/">New part!</a></li>
        </ol>
      '''

@app.route('/read/<id>/')
def readid(id):
     return f"<h1>This is main body contents! Hello {id}!</h1>"

app.run()
# Out:
#  * Serving Flask app "__main__" (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: off
# INFO:werkzeug: * Running on http://127.0.0.1:5000/ (Press CTRL+C to quit)
#  * Running on http://3c18-104-199-114-222.ngrok.io
#  * Traffic stats available on http://127.0.0.1:4040
# INFO:werkzeug:127.0.0.1 - - [24/Sep/2022 06:04:05] "GET / HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [24/Sep/2022 06:04:05] "GET /favicon.ico HTTP/1.1" 404 -
# INFO:werkzeug:127.0.0.1 - - [24/Sep/2022 06:04:08] "GET /read/1/ HTTP/1.1" 200 -

# %% [markdown]
# ## Python 문법 사용
# 파이썬의 속성인 list, dict를 이용해서도 각각에 필요한 HTML코드에 추가해 줄 수 있으며 이를 이용하여 코드를 단축시킬 수 있다.

# %%
app = Flask(__name__)
run_with_ngrok(app)

clicks = [
    {'id':1, 'head':'Click this part!', 'body':'This is main body contents!1'},
    {'id':2, 'head':'Now, click this part!', 'body':'This is main body contents!2'},
    {'id':3, 'head':'New part!', 'body':'This is main body contents!3'}
]

@app.route('/')
def home():
  liTags = ''
  for click in clicks:
    liTags = liTags + f'<li><a href="/read/{click["id"]}">{click["head"]}</a></li>'
  return f'''<!doctype html>
  <html>
      <body>
        <h1>Welcome to your homepage</h1>
        <ol>
          {liTags}
        </ol>
  '''

@app.route('/read/<id>/')
def readid(id):
  num = 0
  body = ''
  while num < len(clicks):
    if str(clicks[num]['id']) == str(id):
      body = body + f"<h1>{clicks[num]['body']}</h1>"
      break
    num += 1
  return body

app.run()
# Out:
#  * Serving Flask app "__main__" (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: off
# INFO:werkzeug: * Running on http://127.0.0.1:5000/ (Press CTRL+C to quit)
#  * Running on http://3b8f-104-199-114-222.ngrok.io
#  * Traffic stats available on http://127.0.0.1:4040
# INFO:werkzeug:127.0.0.1 - - [24/Sep/2022 06:06:19] "GET / HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [24/Sep/2022 06:06:19] "GET /favicon.ico HTTP/1.1" 404 -

# %% [markdown]
# 파이썬에서 함수를 생성하고 함수를 사용하듯 Template 함수를 만들어 HTML의 기본 형식을 지정하고 사용할 수 있다.

# %%
app = Flask(__name__)
run_with_ngrok(app)

clicks = [
    {'id':1, 'head':'Click this part!', 'body':'This is main body contents!1'},
    {'id':2, 'head':'Now, click this part!', 'body':'This is main body contents!2'},
    {'id':3, 'head':'New part!', 'body':'This is main body contents!3'}
]

def template(contents, content):
  return f'''<!doctype html>
  <html>
    <body>
      <h1>Welcome to your homepage</h1>
      <ol>
        {contents}
      </ol>
      {content}
    </body>
  </html>
  '''

def getContents():
  liTags = ''
  for click in clicks:
    liTags = liTags + f'<li><a href="/read/{click["id"]}">{click["head"]}</a></li>'
  return liTags

@app.route('/')
def home():
  return template(getContents(), '<h2>Welcome</h2>Hello, Users!')

@app.route('/read/<id>/')
def readid(id):
  num = 0
  body = ''
  while num < len(clicks):
    if str(clicks[num]['id']) == str(id):
      body = body + f"<h2>{clicks[num]['body']}</h2>"
      break
    num += 1
  return template(getContents(), body)

app.run()
# Out:
#  * Serving Flask app "__main__" (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: off
# INFO:werkzeug: * Running on http://127.0.0.1:5000/ (Press CTRL+C to quit)
#  * Running on http://b686-35-203-138-147.ngrok.io
#  * Traffic stats available on http://127.0.0.1:4040
# INFO:werkzeug:127.0.0.1 - - [17/Aug/2022 07:01:49] "GET / HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [17/Aug/2022 07:01:49] "GET /favicon.ico HTTP/1.1" 404 -
# INFO:werkzeug:127.0.0.1 - - [17/Aug/2022 07:01:50] "GET /read/2 HTTP/1.1" 308 -
# INFO:werkzeug:127.0.0.1 - - [17/Aug/2022 07:01:50] "GET /read/2/ HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [17/Aug/2022 07:01:52] "GET /read/3 HTTP/1.1" 308 -
# INFO:werkzeug:127.0.0.1 - - [17/Aug/2022 07:01:52] "GET /read/3/ HTTP/1.1" 200 -

# %%
app = Flask(__name__)
run_with_ngrok(app)

clicks = [
    {'id':1, 'head':'Click this part!', 'body':'This is main body contents!1'},
    {'id':2, 'head':'Now, click this part!', 'body':'This is main body contents!2'},
    {'id':3, 'head':'New part!', 'body':'This is main body contents!3'}
]

def template(contents, content):
  return f'''<!doctype html>
  <html>
    <body>
      <h1>Welcome to your homepage</h1>
      <ol>
        {contents}
      </ol>
      {content}
    </body>
  </html>
  '''

def getContents():
  liTags = ''
  for click in clicks:
    liTags = liTags + f'<li><a href="/read/{click["id"]}">{click["head"]}</a></li>'
  return liTags

@app.route('/')
def home():
  return template(getContents(), '<h2>Welcome</h2>Hello, Users!')

@app.route('/read/<id>/')
def readid(id):
  num = 0
  body = ''
  while num < len(clicks):
    if str(clicks[num]['id']) == str(id):
      body = body + f"<h2>{clicks[num]['body']}</h2>"
      break
    num += 1
  return template(getContents(), body)

@app.route('/create/')
def create():
    content = '''
    <form action="/create/" method="GET">
      <p><input type="text" name="title" placeholder="title"></p>
      <p><textarea name="body" placeholder="body"></textarea></p>
      <p><input type="submit"></p>
    </form>
  '''
    return template(getContents(), content)

app.run()
# Out:
#  * Serving Flask app "__main__" (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: off
# INFO:werkzeug: * Running on http://127.0.0.1:5000/ (Press CTRL+C to quit)
#  * Running on http://0107-35-221-63-92.ngrok.io
#  * Traffic stats available on http://127.0.0.1:4040

# %% [markdown]
# ## Get 과 Post
# flask내에 있는 request를 불러와 전송 방식을 설정해 줄 수 있다

# %%
from flask import request

# %%
app = Flask(__name__)
run_with_ngrok(app)

clicks = [
    {'id':1, 'head':'Click this part!', 'body':'This is main body contents!1'},
    {'id':2, 'head':'Now, click this part!', 'body':'This is main body contents!2'},
    {'id':3, 'head':'New part!', 'body':'This is main body contents!3'}
]

def template(contents, content):
  return f'''
  <!doctype html>
  <html>
    <body>  
      <h1>Welcome to your homepage</h1>
      <ol>
        {contents}  
      </ol>
      {content}
    </body>
  </html>
  '''

def getContents():   
  liTags = ''
  for click in clicks:
    liTags = liTags + f'<li><a href="/read/{click["id"]}">{click["head"]}</a></li>' 
  return liTags

@app.route('/')
def home():
  return template(getContents(), '<h2>Welcome</h2>Hello, Users!') 

@app.route('/read/<id>/')
def readid(id):
#   num = 0
#   body = ''
#   while num < len(clicks):
#     if str(clicks[num]['id']) == str(id):
#       body = body + f"<h2>{clicks[num]['body']}</h2>"
#       break
#     num += 1
#   return template(getContents(), body)

  body= f"<h1>thi is main body! hello {id}!</h1>"
  return template(getContents(), body)


@app.route('/create/', methods=['GET', 'POST'])
def create():
  if request.method == "GET":
    content = '''
      <form action="/create/" method="GET">
        <p><input type="text" name="title" placeholder="title"></p>
        <p><textarea name="body" placeholder="body"></textarea></p>
        <p><input type="submit"></p>
      </form>
    '''
    return template(getContents(), content)
  elif request.method == "POST":
    return 'Hello Post'

app.run()
# Out:
#  * Serving Flask app "__main__" (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: off
# INFO:werkzeug: * Running on http://127.0.0.1:5000/ (Press CTRL+C to quit)
# Exception in thread Thread-45:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.7/dist-packages/urllib3/connection.py", line 159, in _new_conn
#     (self._dns_host, self.port), self.timeout, **extra_kw)
#   File "/usr/local/lib/python3.7/dist-packages/urllib3/util/connection.py", line 80, in create_connection
#     raise err
#   File "/usr/local/lib/python3.7/dist-packages/urllib3/util/connection.py", line 70, in create_connection
#     sock.connect(sa)
# ConnectionRefusedError: [Errno 111] Connection refused
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.7/dist-packages/urllib3/connectionpool.py", line 600, in urlopen
#     chunked=chunked)
#   File "/usr/local/lib/python3.7/dist-packages/urllib3/connectionpool.py", line 354, in _make_request
#     conn.request(method, url, **httplib_request_kw)
#   File "/usr/lib/python3.7/http/client.py", line 1281, in request
#     self._send_request(method, url, body, headers, encode_chunked)
#   File "/usr/lib/python3.7/http/client.py", line 1327, in _send_request
#     self.endheaders(body, encode_chunked=encode_chunked)
#   File "/usr/lib/python3.7/http/client.py", line 1276, in endheaders
#     self._send_output(message_body, encode_chunked=encode_chunked)
#   File "/usr/lib/python3.7/http/client.py", line 1036, in _send_output
#     self.send(msg)
#   File "/usr/lib/python3.7/http/client.py", line 976, in send
#     self.connect()
#   File "/usr/local/lib/python3.7/dist-packages/urllib3/connection.py", line 181, in connect
#     conn = self._new_conn()
#   File "/usr/local/lib/python3.7/dist-packages/urllib3/connection.py", line 168, in _new_conn
#     self, "Failed to establish a new connection: %s" % e)
# urllib3.exceptions.NewConnectionError: <urllib3.connection.HTTPConnection object at 0x7f608cb31390>: Failed to establish a new connection: [Errno 111] Connection refused
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.7/dist-packages/requests/adapters.py", line 449, in send
#     timeout=timeout
#   File "/usr/local/lib/python3.7/dist-packages/urllib3/connectionpool.py", line 638, in urlopen
#     _stacktrace=sys.exc_info()[2])
#   File "/usr/local/lib/python3.7/dist-packages/urllib3/util/retry.py", line 399, in increment
#     raise MaxRetryError(_pool, url, error or ResponseError(cause))
# urllib3.exceptions.MaxRetryError: HTTPConnectionPool(host='localhost', port=4040): Max retries exceeded with url: /api/tunnels (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7f608cb31390>: Failed to establish a new connection: [Errno 111] Connection refused'))
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/lib/python3.7/threading.py", line 926, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.7/threading.py", line 1177, in run
#     self.function(*self.args, **self.kwargs)
#   File "/usr/local/lib/python3.7/dist-packages/flask_ngrok.py", line 70, in start_ngrok
#     ngrok_address = _run_ngrok()
#   File "/usr/local/lib/python3.7/dist-packages/flask_ngrok.py", line 35, in _run_ngrok
#     tunnel_url = requests.get(localhost_url).text  # Get the tunnel information
#   File "/usr/local/lib/python3.7/dist-packages/requests/api.py", line 76, in get
#     return request('get', url, params=params, **kwargs)
#   File "/usr/local/lib/python3.7/dist-packages/requests/api.py", line 61, in request
#     return session.request(method=method, url=url, **kwargs)
#   File "/usr/local/lib/python3.7/dist-packages/requests/sessions.py", line 530, in request
#     resp = self.send(prep, **send_kwargs)
#   File "/usr/local/lib/python3.7/dist-packages/requests/sessions.py", line 643, in send
#     r = adapter.send(request, **kwargs)
#   File "/usr/local/lib/python3.7/dist-packages/requests/adapters.py", line 516, in send
#     raise ConnectionError(e, request=request)
# requests.exceptions.ConnectionError: HTTPConnectionPool(host='localhost', port=4040): Max retries exceeded with url: /api/tunnels (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7f608cb31390>: Failed to establish a new connection: [Errno 111] Connection refused'))

# %% [markdown]
# # HTML과 CSS, JS를 이용한 예시

# %%
from flask import Flask, url_for, redirect, render_template, request
from flask_ngrok import run_with_ngrok
import os

# %%
TEMPLATE_FOLDER = '/content'
STATIC_FOLDER = '/content/static'
app = Flask(__name__, template_folder=TEMPLATE_FOLDER, static_folder = STATIC_FOLDER)
run_with_ngrok(app)   

@app.route('/')
def index():
    return render_template('index.html', image_path='img/tmp_image.jpg', css_path='css/index.css', js_path='index.js')

app.run()
# Out:
#  * Serving Flask app "__main__" (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: off
# INFO:werkzeug: * Running on http://127.0.0.1:5000/ (Press CTRL+C to quit)
#  * Running on http://005f-35-203-138-147.ngrok.io
#  * Traffic stats available on http://127.0.0.1:4040
# INFO:werkzeug:127.0.0.1 - - [17/Aug/2022 08:44:11] "GET / HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [17/Aug/2022 08:44:12] "GET /static/css/style.css HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [17/Aug/2022 08:44:12] "GET /static/images/photo-1.jpg HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [17/Aug/2022 08:44:12] "GET /static/images/photo-3.jpg HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [17/Aug/2022 08:44:12] "GET /static/images/photo-2.jpg HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [17/Aug/2022 08:44:12] "GET /static/js/slideshow.js HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [17/Aug/2022 08:44:12] "GET /static/images/img-1.jpg HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [17/Aug/2022 08:44:12] "GET /static/images/img-2.jpg HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [17/Aug/2022 08:44:12] "GET /static/images/icon-3.jpg HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [17/Aug/2022 08:44:12] "GET /static/images/icon-1.jpg HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [17/Aug/2022 08:44:12] "GET /static/images/icon-2.jpg HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [17/Aug/2022 08:44:13] "GET /static/images/img-3.jpg HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [17/Aug/2022 08:44:13] "GET /static/images/sns-2.png HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [17/Aug/2022 08:44:13] "GET /static/images/sns-1.png HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [17/Aug/2022 08:44:13] "GET /static/images/sns-3.png HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [17/Aug/2022 08:44:13] "GET /favicon.ico HTTP/1.1" 404 -
# INFO:werkzeug:127.0.0.1 - - [17/Aug/2022 08:44:16] "GET /index.html HTTP/1.1" 404 -
# INFO:werkzeug:127.0.0.1 - - [17/Aug/2022 08:44:16] "GET /index.html HTTP/1.1" 404 -
# INFO:werkzeug:127.0.0.1 - - [17/Aug/2022 08:47:11] "GET / HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [17/Aug/2022 08:47:17] "GET / HTTP/1.1" 200 -
